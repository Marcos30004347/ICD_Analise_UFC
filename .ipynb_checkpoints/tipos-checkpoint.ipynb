# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import scipy as spy

# %%
columns = [
    "R_fighter",
    "B_fighter",
    "Winner","weight_class",
    "no_of_rounds",
    "B_wins", 
    "R_wins", 
    "B_losses", 
    "R_losses", 
    "B_age", 
    "R_age", 
    "R_Height_cms",
    "R_Reach_cms",
    "R_Weight_lbs",
    "B_Height_cms",
    "B_Reach_cms",
    "B_Weight_lbs",
    "R_win_by_Submission",
    "R_win_by_Decision_Majority",
    "R_win_by_Decision_Split",
    "R_win_by_Decision_Unanimous",
    "R_win_by_KO/TKO",
    "R_win_by_TKO_Doctor_Stoppage",
    "B_win_by_Submission",
    "B_win_by_Decision_Majority",
    "B_win_by_Decision_Split",
    "B_win_by_Decision_Unanimous",
    "B_win_by_KO/TKO",
    "B_win_by_TKO_Doctor_Stoppage"]
data = pd.read_csv("ufcdata/data.csv",encoding='latin-1', usecols=columns)
data.head()
# Out:
#               R_fighter       B_fighter Winner       weight_class  \
# 0          Henry Cejudo   Marlon Moraes    Red       Bantamweight
# 1  Valentina Shevchenko     Jessica Eye    Red  Women's Flyweight
# 2         Tony Ferguson  Donald Cerrone    Red        Lightweight
# 3         Jimmie Rivera        Petr Yan   Blue       Bantamweight
# 4           Tai Tuivasa   Blagoy Ivanov   Blue        Heavyweight
#
#    no_of_rounds  B_losses  B_win_by_Decision_Majority  \
# 0             5       1.0                         0.0
# 1             5       6.0                         0.0
# 2             3       8.0                         0.0
# 3             3       0.0                         0.0
# 4             3       1.0                         0.0
#
#    B_win_by_Decision_Split  B_win_by_Decision_Unanimous  B_win_by_KO/TKO  ...  \
# 0                      1.0                          0.0              2.0  ...
# 1                      2.0                          1.0              0.0  ...
# ...

# %%
data["R_age"].plot.hist(bins=10, alpha=0.5, color='red')

# %%
data["B_age"].plot.hist(bins=10, alpha=0.5)

# %%
nomeR = data["B_fighter"] == "Henry Cejudo"
pimba = data[nomeR]["B_wins"]
pey = data[nomeR]["B_wins"].max()
final = data[nomeR]["B_wins"] == pey
print("value = ",data[nomeR][final]["Winner"])
#pey = data[nomeR][pimba]
#pimba = data[nomeR][pey]
#data["R_wins"]
#nome = max(max(nomeR["R_wins"]),max(nomeB["B_wins"]))
# Out:
# value =  412    Blue
# Name: Winner, dtype: object

# %%
dec = 0
sub = 0
ko = 0
types = data.copy()

import math

types.dropna()
print(types)
for name in types["R_fighter"]:
    name_R = types["R_fighter"] == name
    name_B = types["B_fighter"] == name
    max_R = types[name_R]["R_wins"].max()
    max_B = types[name_B]["B_wins"].max()
    
    if(max_R != 0 and not math.isnan(max_R) and max_B != 0 and not math.isnan(max_B)):
        #print("le", max_R,max_B)
        if(max_R >= max_B):
            tupla_max = types[name_R]["R_wins"] == max_R
            
            win_by_Decision = types[name_R][tupla_max]['R_win_by_Decision_Split'].max();
            win_by_Decision_Majority = types[name_R][tupla_max]['R_win_by_Decision_Majority'].max()
            win_by_Unanimous = types[name_R][tupla_max]['R_win_by_Decision_Unanimous'].max()
            win_by_submission = types[name_R][tupla_max]['R_win_by_Submission'].max()
            win_by_ko = types[name_R][tupla_max]['R_win_by_KO/TKO'].max()
            win_by_stoppage = types[name_R][tupla_max]['R_win_by_TKO_Doctor_Stoppage'].max()
            print(win_by_Decision)
            #print(win_by_Decision, win_by_Decision_Majority, win_by_Unanimous, win_by_submission, win_by_ko, win_by_stoppage)
            
            dec = dec + win_by_Decision_Majority + win_by_Decision + win_by_Unanimous
            sub = sub + win_by_submission
            ko = ko + win_by_ko + win_by_stoppage

        else:
            tupla_max = types[name_B]["B_wins"] == max_B
            
            win_by_Decision = types[name_R][tupla_max]['B_win_by_Decision_Split'].max();
            win_by_Decision_Majority = types[name_R][tupla_max]['B_win_by_Decision_Majority'].max()
            win_by_Unanimous = types[name_R][tupla_max]['B_win_by_Decision_Unanimous'].max()
            win_by_submission = types[name_R][tupla_max]['B_win_by_Submission'].max()
            win_by_ko = types[name_R][tupla_max]['B_win_by_KO/TKO'].max()
            win_by_stoppage = types[name_R][tupla_max]['B_win_by_TKO_Doctor_Stoppage'].max()
            print(win_by_Decision)

            #print(win_by_Decision, win_by_Decision_Majority, win_by_Unanimous, win_by_submission, win_by_ko, win_by_stoppage)

            dec = dec + win_by_Decision_Majority + win_by_Decision + win_by_Unanimous

            sub = sub + win_by_submission

            ko = ko + win_by_ko + win_by_stoppage

            
        #print(dec,sub,ko)
# Out:
#                  R_fighter       B_fighter Winner       weight_class  \
# 0             Henry Cejudo   Marlon Moraes    Red       Bantamweight
# 1     Valentina Shevchenko     Jessica Eye    Red  Women's Flyweight
# 2            Tony Ferguson  Donald Cerrone    Red        Lightweight
# 3            Jimmie Rivera        Petr Yan   Blue       Bantamweight
# 4              Tai Tuivasa   Blagoy Ivanov   Blue        Heavyweight
# ...                    ...             ...    ...                ...
# 5139        Gerard Gordeau    Kevin Rosier    Red        Open Weight
# 5140          Ken Shamrock   Patrick Smith    Red        Open Weight
# 5141          Royce Gracie   Art Jimmerson    Red        Open Weight
# 5142          Kevin Rosier    Zane Frazier    Red        Open Weight
# 5143        Gerard Gordeau      Teila Tuli    Red        Open Weight
#
#       no_of_rounds  B_losses  B_win_by_Decision_Majority  \
# 0                5       1.0                         0.0
# ...
